# %%
def mergeAlternately(word1, word2):
    merged = ''.join(a + b for a, b in zip(word1, word2))
    return merged + word1[len(word2):] + word2[len(word1):]

# %%
mergeAlternately('abc', 'pqrst')
# Out:
# 'apbqcrst'

# %%
word1 = 'abc'
word2 = 'pqrst'
word3 = []

# %%
for a, b in zip(word1, word2):
    word3.append(a+b)
word3 = ''.join(word3)
print(word3 + word1[len(word2):] + word2[len(word1):])
# Out:
# apbqcrst
